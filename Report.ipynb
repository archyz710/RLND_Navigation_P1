# %% [markdown]
# # Project 1: Navigation
#
#
# ## Project details:
# An DQN agent is trained to navigate (and collect yellow bananas) in a large square world. A reward of +1 is provided for collecting a yellow banana, and a reward of -1 is provided for collecting a blue banana. Thus, the goal of your agent is to collect as many yellow bananas as possible while avoiding blue bananas.
#
# The state space has 37 dimensions and contains the agent's velocity, along with ray-based perception of objects around the agent's forward direction. Given this information, the agent has to learn how to best select actions. Four discrete actions are available, corresponding to:
#
# 0 - move forward.
#
# 1 - move backward.
#
# 2 - turn left.
#
# 3 - turn right.
#
# The task is episodic, and in order to solve the environment, your agent must get an average score of +13 over 100 consecutive episodes.
#
# ## Learning Algorithm:
#
# The agent is based on Deep-Q-Network algorithm. A deep Neural Network model is used to approximate the state-value function. The network is trained using Q-learning technique and Experience Replay.
#
# ### The network:
# Inputs: system states (total of 37 states)
# Outputs: value for each action (total of 4 actions)
# Hidden Layer 1: fully connected 64 neurons, Relu activation function
# Hidden Layer 2: fully connected 64 neurons, Relu activation function
#
# ### The Q-learning algorithm
# The Q-learning utilizes epsilon-greedy method. The epsilon is selected as 1 at the beginning of the training process to allow more exploration. It delays at a rate of 0.995 to shift the balance to exploitation as the agent gets better. It terminates at 0.01 to allow some exploration.
#
# Experience Replay method was applied to eliminate data correlation and improve training performance. The experience buffer is selected sufficiently large (1e5) to store enough experiences. The DQN is updated with mini batch of 64 samples, randomly selected from the experience buffer.
#
# Fixed Q-Target technique was applied to improve training performance. While the primary Q-network is updated in every epoch, the DQN used to compute TD target is updated in every 4-step interval.
#
# ### Plot of rewards:
# The following figure shows the score (average of 100 episodes) evolution with training episodes. The score went above 13 at 505th episode:
#
# ![image.png](attachment:image.png)
#
# ### Future improvement:
# I am very satisfied with the current DQN performance. Further investigation will be focused on:
#
# 1. Visualize the agent in the Unity environment
#
# 2. Apply other techniques, like double DQN, dueling DQN and prioritized experience replay from the lecture
